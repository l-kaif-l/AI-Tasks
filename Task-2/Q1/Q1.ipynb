# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv( "./TCS.csv" )
df
# Out:
#             Date Symbol Series  Prev Close     Open     High      Low  \
# 0     2004-08-25    TCS     EQ      850.00  1198.70  1198.70   979.00
# 1     2004-08-26    TCS     EQ      987.95   992.00   997.00   975.30
# 2     2004-08-27    TCS     EQ      979.00   982.40   982.40   958.55
# 3     2004-08-30    TCS     EQ      962.65   969.90   990.00   965.00
# 4     2004-08-31    TCS     EQ      986.75   986.50   990.00   976.00
# ...          ...    ...    ...         ...      ...      ...      ...
# 4134  2021-04-26    TCS     EQ     3109.50  3102.05  3153.00  3088.05
# 4135  2021-04-27    TCS     EQ     3100.80  3106.00  3136.10  3103.00
# 4136  2021-04-28    TCS     EQ     3132.00  3149.95  3151.00  3112.00
# 4137  2021-04-29    TCS     EQ     3124.10  3145.60  3157.35  3105.50
# 4138  2021-04-30    TCS     EQ     3115.25  3099.00  3132.05  3020.00
#
#          Last    Close     VWAP    Volume      Turnover    Trades  \
# ...

# %%
df = df.truncate(after = 28)
df
# Out:
#           Date Symbol Series  Prev Close     Open     High      Low     Last  \
# 0   2004-08-25    TCS     EQ      850.00  1198.70  1198.70   979.00   985.00
# 1   2004-08-26    TCS     EQ      987.95   992.00   997.00   975.30   976.85
# 2   2004-08-27    TCS     EQ      979.00   982.40   982.40   958.55   961.20
# 3   2004-08-30    TCS     EQ      962.65   969.90   990.00   965.00   986.40
# 4   2004-08-31    TCS     EQ      986.75   986.50   990.00   976.00   987.80
# 5   2004-09-01    TCS     EQ      988.10   990.00   995.00   983.60   986.00
# 6   2004-09-02    TCS     EQ      987.90   989.90  1004.60   986.00   994.00
# 7   2004-09-03    TCS     EQ      993.65  1006.00  1100.00   990.35   998.70
# 8   2004-09-06    TCS     EQ      997.85  1039.90  1039.90   992.90   996.80
# 9   2004-09-07    TCS     EQ      994.85  1035.00  1035.00   995.00   995.00
# 10  2004-09-08    TCS     EQ      995.60   996.00  1000.80   991.10   992.25
# ...

# %%
b_plot = sns.barplot( x = df["Date"], y = df["Volume"] )
plt.draw()
b_plot.set_xticklabels( b_plot.get_xticklabels() , rotation = 90 )
print()

# %%
h_plot = sns.histplot( x = df["Date"], y = df["High"] )
plt.draw()
h_plot.set_xticklabels( h_plot.get_xticklabels() , rotation = 90 )
print()
# Out:
# C:\Users\straw\AppData\Local\Temp\ipykernel_816\4013549849.py:3: UserWarning: FixedFormatter should only be used together with FixedLocator
#   h_plot.set_xticklabels( h_plot.get_xticklabels() , rotation = 90 )

# %%
sc_plot = sns.scatterplot( x = df["Date"], y = df["Low"] )
plt.draw()
sc_plot.set_xticklabels( sc_plot.get_xticklabels() , rotation = 90 )
print()
# Out:
# C:\Users\straw\AppData\Local\Temp\ipykernel_816\4216932042.py:3: UserWarning: FixedFormatter should only be used together with FixedLocator
#   sc_plot.set_xticklabels( sc_plot.get_xticklabels() , rotation = 90 )

# %%
corr_mat = df.corr() 
# sns.barplot( x = df["Date"], y = df["Volume"] )
sns.heatmap( corr_mat  )
# Out:
# <AxesSubplot:>
